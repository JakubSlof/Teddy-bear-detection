# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import chi2

# %%
x_data = np.array([15,87,138,178,206,228,246,260,274,283,291,300,307])
y_data = np.array([40,50,60,70,80,90,100,110,120,130,140,150,160])

# %%
ylog_data = np.log(y_data)
curve_fit = np.polyfit(x_data, ylog_data,1)
print(curve_fit)
a,b = curve_fit
# Out:
# [0.0047974 3.486047 ]

# %%
y= np.exp(b)*np.exp(0.0045*x_data)
print(y)
# Out:
# [ 34.93701968  48.30557618  60.76700756  72.75131656  82.52052109
#   91.10812636  98.79500066 105.21932729 112.06140757 116.69305231
#  120.97053492 125.97040556 130.00163183]

# %%
plt.scatter(x_data,y_data,color='r')
plt.plot(x_data,y)

# %%
print('np.exp(',b,')*np.exp(0.0045*x_data)')
# Out:
# np.exp( 3.486047002894599 )*np.exp(0.0045*x_data)
